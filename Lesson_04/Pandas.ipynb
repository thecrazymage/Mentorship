# %% [markdown]
# В машинном обучении, как правило, всё сводится к анализу табличных данных. Начинать мы можем с большого количества сложных таблиц, изображений, текстов или ещё чего-то непростого, но в итоге всё это обычно сводится к одной таблице, где каждый объект описывается набором признаков. Поэтому важно уметь работать с таблицами.
#
# А ещё есть некоторые исследования, показывающие, что в решении задачи интеллектуального анализа данных обычно 20% времени уходит на построение моделей и прочую интересную работу, связанную с тем, что рассказывается у нас на лекциях, а 80% времени специалисты тратят на подготовку и обработку данных. Сюда входит формирование признаков, устранение выбросов и пропусков и т.д. И это тоже, по сути дела, манипуляции с таблицами.
#
# Вывод: важно уметь работать с табличными данными. В Python для этого есть библиотека pandas, которую мы и будем сегодня изучать.

# %% [markdown]
# Чаще всего название библиотеки при импорте сокращают до "pd":

# %%
import pandas as pd

# %% [markdown]
# ### Распределение студентов по элективам

# %% [markdown]
# Разумно тренироваться на реальных сложных данных. А что может быть более сложным, чем данные, сгенерированные студентами?
#
# Сегодня мы будем работать с анкетами студентов ПМИ 2017 и 2018 годов набора о том, на какие курсы по выбору они хотят попасть. Данные были анонимизированы: ФИО захешированы с солью, к рейтингам добавлен случайный шум.
#
# *Вопрос: как можно деанонимизировать данные после манипуляций, которые мы проделали? А как бы вы предложили провести анонимизацию?*

# %% [markdown]
# У нас есть 2 таблицы (для 3 и 4 курса):
#
#     – 'Timestamp': время получения ответов
#     – 'ID': ID студента (может повторяться, если студент больше одного раза заполнял анкету)
#     – 'Рейтинг': Кредитно-рейтинговая сумма студента (грубо говоря, сумма оценок студента по всем его дисциплинам с весами — чем дольша шла дисциплина, тем больше вес; подробности тут: https://www.hse.ru/studyspravka/rate/)
#     – 'Группа (в формате 182)': Номер группы
#     – 'МИ?': 1, если студент распределился на специализацию МИ, или NaN в противном случае (признак важен, поскольку студенты МИ берут осенью два курса по выбору, а студенты остальных специализаций только один)
#     – 'Осенний курс по выбору, приоритет 1'
#     – 'Осенний курс по выбору, приоритет 2'
#     – 'Осенний курс по выбору, приоритет 3'
#     – 'Весенний курс по выбору, приоритет 1'
#     – 'Весенний курс по выбору, приоритет 2'
#     – 'Весенний курс по выбору, приоритет 3'
#     – 'Вы заполняете анкету в первый раз?': "Да" или "Нет"
#
# Дополнительные столбцы для 4ого курса:
#
#     – 'Группа (в формате 173)': Номер группы
#     – 'blended-курс': Выбор blended-курса (кол-во мест неограничено)

# %% [markdown]
# Загрузим данные (обратите внимание, что мы легко читаем xlsx-файлы):

# %%
# !wget  -O 'data_3_course.xlsx' -q 'https://www.dropbox.com/s/ysxs5srafoyxknb/_data_3_course.xlsx?dl=1'
# !wget  -O 'data_4_course.xlsx' -q 'https://www.dropbox.com/s/hfg2mzmvcivtxqk/_data_4_course.xlsx?dl=1'

# %%
data3 = pd.read_excel('data_3_course.xlsx')
data4 = pd.read_excel('data_4_course.xlsx')

# %%
data3
# Out:
#                   Timestamp                                ID Рейтинг  \
# 0   2020-05-15 01:12:50.543  93ff79a51cd602f1dd3028ba2c129503   704,0
# 1   2020-05-15 02:46:48.066  26b01b1c4cd5656bab18d24c548834fb   646,0
# 2   2020-05-15 03:12:41.480  30f3653fc176d54e89ac3179c455c6dd   624,0
# 3   2020-05-15 04:43:08.994  1528f0eaa027580820ccf0d92a53ad68   579,0
# 4   2020-05-15 07:47:17.197  496ea4f0d4abe264b1bb1b80eb3830c5   632,0
# ..                      ...                               ...     ...
# 218 2020-05-20 11:49:38.801  bd416140ecdb32b6dbd7f40820bf63b1   517,0
# 219 2020-05-20 11:57:07.326  e6f5eb76b34e7ab7bac753e6cb0a2279   634,0
# 220 2020-05-21 16:33:15.899  1341f488fae5f1ccf164960fd6506cd0   584,0
# 221 2020-05-24 01:21:31.946  04bcb5c9d23813ffa940e1febb27fadc   646,0
# 222 2020-05-19 04:24:29.000  9d19b0d5f4fc8d7edc2258406f872c4e   694,0
#
#      Группа (в формате 182)  МИ? Осенний курс по выбору, приоритет 1  \
# 0                       181  NaN                            Язык SQL
# 1                       181  NaN   Высокопроизводительные вычисления
# 2                       185  NaN    Безопасность компьютерных систем
# 3                       182  NaN         Statistical Learning Theory
# 4                       183  NaN   Высокопроизводительные вычисления
# ..                      ...  ...                                 ...
# 218                     185  NaN    Безопасность компьютерных систем
# 219                     184  NaN                   Теория баз данных
# 220                     188  NaN                            Язык SQL
# 221                     186  NaN                   Теория баз данных
# 222                     188  NaN    Безопасность компьютерных систем
#
#     Осенний курс по выбору, приоритет 2 Осенний курс по выбору, приоритет 3  \
# 0     Высокопроизводительные вычисления                Матричные вычисления
# 1      Безопасность компьютерных систем                            Язык SQL
# 2                  Матричные вычисления       Моделирование временных рядов
# 3     Высокопроизводительные вычисления                Матричные вычисления
# 4      Безопасность компьютерных систем                   Теория баз данных
# ..                                  ...                                 ...
# 218                   Теория баз данных                            Язык SQL
# 219    Безопасность компьютерных систем       Моделирование временных рядов
# 220                   Теория баз данных    Безопасность компьютерных систем
# 221   Высокопроизводительные вычисления    Безопасность компьютерных систем
# 222                            Язык SQL   Высокопроизводительные вычисления
#
#             Весенний курс по выбору, приоритет 1  \
# 0                         Дискретная оптимизация
# 1                         Дискретная оптимизация
# 2                         Дискретная оптимизация
# 3                         Дискретная оптимизация
# 4                              Компьютерные сети
# ..                                           ...
# 218                          Машинное обучение 2
# 219                            Компьютерные сети
# 220  Промышленное программирование на языке Java
# 221                            Компьютерные сети
# 222                            Компьютерные сети
#
#             Весенний курс по выбору, приоритет 2  \
# 0                               Численные методы
# 1                               Численные методы
# 2                            Машинное обучение 2
# 3                               Численные методы
# 4                         Дискретная оптимизация
# ..                                           ...
# 218                            Компьютерные сети
# 219  Промышленное программирование на языке Java
# 220                            Компьютерные сети
# 221                       Дискретная оптимизация
# 222                       Дискретная оптимизация
#
#             Весенний курс по выбору, приоритет 3  \
# 0                            Машинное обучение 2
# 1                            Машинное обучение 2
# 2                               Численные методы
# 3                            Машинное обучение 2
# 4                               Численные методы
# ..                                           ...
# 218  Промышленное программирование на языке Java
# 219                      Анализ данных в бизнесе
# 220                           Системы баз данных
# 221                          Машинное обучение 2
# 222                             Численные методы
#
#     Вы заполняете анкету в первый раз?
# 0                                   Да
# 1                                  Нет
# 2                                   Да
# 3                                   Да
# 4                                   Да
# ..                                 ...
# 218                                 Да
# 219                                 Да
# 220                                 Да
# 221                                Нет
# 222                                NaN
#
# [223 rows x 12 columns]

# %% [markdown]
# Посмотрим размер таблицы:

# %%
data3.shape
# Out:
# (223, 12)

# %% [markdown]
# Для начала будем работать с одной таблицей для 3 курса. Теперь данные хранятся в переменной ```data3```, которая имеет тип [DataFrame](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html):

# %%
type(data3)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# DataFrame можно создать и вручную:

# %%
df = pd.DataFrame({
    'AAA': [4, 5, 6, 7],
    'BBB': [10, None, None, None],
    'CCC': ['R', 50, 'E', -50]
})
df
# Out:
#    AAA   BBB  CCC
# 0    4  10.0    R
# 1    5   NaN   50
# 2    6   NaN    E
# 3    7   NaN  -50

# %% [markdown]
# DataFrame можно частично отобразить в jupyter-ноутбуке с помощью методов ```head```(первые строки) и ```sample```(случайные строки):

# %%
data3.head(250)
# Out:
#                   Timestamp                                ID Рейтинг  \
# 0   2020-05-15 01:12:50.543  93ff79a51cd602f1dd3028ba2c129503   704,0
# 1   2020-05-15 02:46:48.066  26b01b1c4cd5656bab18d24c548834fb   646,0
# 2   2020-05-15 03:12:41.480  30f3653fc176d54e89ac3179c455c6dd   624,0
# 3   2020-05-15 04:43:08.994  1528f0eaa027580820ccf0d92a53ad68   579,0
# 4   2020-05-15 07:47:17.197  496ea4f0d4abe264b1bb1b80eb3830c5   632,0
# ..                      ...                               ...     ...
# 218 2020-05-20 11:49:38.801  bd416140ecdb32b6dbd7f40820bf63b1   517,0
# 219 2020-05-20 11:57:07.326  e6f5eb76b34e7ab7bac753e6cb0a2279   634,0
# 220 2020-05-21 16:33:15.899  1341f488fae5f1ccf164960fd6506cd0   584,0
# 221 2020-05-24 01:21:31.946  04bcb5c9d23813ffa940e1febb27fadc   646,0
# 222 2020-05-19 04:24:29.000  9d19b0d5f4fc8d7edc2258406f872c4e   694,0
#
#      Группа (в формате 182)  МИ? Осенний курс по выбору, приоритет 1  \
# 0                       181  NaN                            Язык SQL
# 1                       181  NaN   Высокопроизводительные вычисления
# 2                       185  NaN    Безопасность компьютерных систем
# 3                       182  NaN         Statistical Learning Theory
# 4                       183  NaN   Высокопроизводительные вычисления
# ..                      ...  ...                                 ...
# 218                     185  NaN    Безопасность компьютерных систем
# 219                     184  NaN                   Теория баз данных
# 220                     188  NaN                            Язык SQL
# 221                     186  NaN                   Теория баз данных
# 222                     188  NaN    Безопасность компьютерных систем
#
#     Осенний курс по выбору, приоритет 2 Осенний курс по выбору, приоритет 3  \
# 0     Высокопроизводительные вычисления                Матричные вычисления
# 1      Безопасность компьютерных систем                            Язык SQL
# 2                  Матричные вычисления       Моделирование временных рядов
# 3     Высокопроизводительные вычисления                Матричные вычисления
# 4      Безопасность компьютерных систем                   Теория баз данных
# ..                                  ...                                 ...
# 218                   Теория баз данных                            Язык SQL
# 219    Безопасность компьютерных систем       Моделирование временных рядов
# 220                   Теория баз данных    Безопасность компьютерных систем
# 221   Высокопроизводительные вычисления    Безопасность компьютерных систем
# 222                            Язык SQL   Высокопроизводительные вычисления
#
#             Весенний курс по выбору, приоритет 1  \
# 0                         Дискретная оптимизация
# 1                         Дискретная оптимизация
# 2                         Дискретная оптимизация
# 3                         Дискретная оптимизация
# 4                              Компьютерные сети
# ..                                           ...
# 218                          Машинное обучение 2
# 219                            Компьютерные сети
# 220  Промышленное программирование на языке Java
# 221                            Компьютерные сети
# 222                            Компьютерные сети
#
#             Весенний курс по выбору, приоритет 2  \
# 0                               Численные методы
# 1                               Численные методы
# 2                            Машинное обучение 2
# 3                               Численные методы
# 4                         Дискретная оптимизация
# ..                                           ...
# 218                            Компьютерные сети
# 219  Промышленное программирование на языке Java
# 220                            Компьютерные сети
# 221                       Дискретная оптимизация
# 222                       Дискретная оптимизация
#
#             Весенний курс по выбору, приоритет 3  \
# 0                            Машинное обучение 2
# 1                            Машинное обучение 2
# 2                               Численные методы
# 3                            Машинное обучение 2
# 4                               Численные методы
# ..                                           ...
# 218  Промышленное программирование на языке Java
# 219                      Анализ данных в бизнесе
# 220                           Системы баз данных
# 221                          Машинное обучение 2
# 222                             Численные методы
#
#     Вы заполняете анкету в первый раз?
# 0                                   Да
# 1                                  Нет
# 2                                   Да
# 3                                   Да
# 4                                   Да
# ..                                 ...
# 218                                 Да
# 219                                 Да
# 220                                 Да
# 221                                Нет
# 222                                NaN
#
# [223 rows x 12 columns]

# %%
data3.sample(5)
# Out:
#                   Timestamp                                ID Рейтинг  \
# 47  2020-05-17 14:04:41.159  34f75b81eb7b1cc9e9e4ef5bfd7fa69a   677,0
# 161 2020-05-18 22:08:11.668  00b40fe7dbfd23e5daba765244509415   637,0
# 205 2020-05-18 23:55:54.625  5ab47e4eef1a7c1899da4da200049038   649,0
# 74  2020-05-18 16:11:14.717  635e9ca4fcf26a2bd38b8488a8edfca5   641,0
# 6   2020-05-15 11:42:16.910  e4caca755ee0bdd711e18fb8084958b5   723,0
#
#      Группа (в формате 182)  МИ?  \
# 47                      184  NaN
# 161                     187  NaN
# 205                     184  1.0
# 74                      186  NaN
# 6                       181  NaN
#
#                  Осенний курс по выбору, приоритет 1  \
# 47                  Безопасность компьютерных систем
# 161                 Безопасность компьютерных систем
# 205                    Моделирование временных рядов
# 74   Сбор и обработка данных с помощью краудсорсинга
# 6                        Statistical Learning Theory
#
#     Осенний курс по выбору, приоритет 2  \
# 47        Моделирование временных рядов
# 161                            Язык SQL
# 205                Матричные вычисления
# 74     Безопасность компьютерных систем
# 6      Безопасность компьютерных систем
#
#                    Осенний курс по выбору, приоритет 3  \
# 47                   Высокопроизводительные вычисления
# 161                               Матричные вычисления
# 205  Принятие решений в условиях риска и неопределё...
# 74                                            Язык SQL
# 6                        Моделирование временных рядов
#
#             Весенний курс по выбору, приоритет 1  \
# 47                           Машинное обучение 2
# 161  Промышленное программирование на языке Java
# 205                             Численные методы
# 74    Дополнительные главы прикладной статистики
# 6                               Численные методы
#
#             Весенний курс по выбору, приоритет 2  \
# 47   Промышленное программирование на языке Java
# 161                            Компьютерные сети
# 205                      Анализ данных в бизнесе
# 74                            Системы баз данных
# 6    Промышленное программирование на языке Java
#
#            Весенний курс по выбору, приоритет 3  \
# 47   Дополнительные главы прикладной статистики
# 161                     Анализ данных в бизнесе
# 205  Дополнительные главы прикладной статистики
# 74                            Компьютерные сети
# 6                           Машинное обучение 2
#
#     Вы заполняете анкету в первый раз?
# 47                                  Да
# 161                                 Да
# 205                                 Да
# 74                                  Да
# 6                                   Да

# %% [markdown]
# Можно немного залезть во внутренности Jupyter, чтобы отобразить сразу несколько таблиц:

# %%
from IPython.display import display
display(data3.sample(3)), display(data3.head(3))
# Out:
#                   Timestamp                                ID Рейтинг  \
# 43  2020-05-17 12:04:22.843  b6bf56b8b8ffd1666036b0a8ca01c452   599,0
# 203 2020-05-18 23:54:02.617  6a93b58f867db41e822a03c26c1bd428   586,0
# 166 2020-05-18 22:15:41.331  b4f1f195bd1bc63490a7bc42275a71cd   536,0
#
#      Группа (в формате 182)  МИ?  \
# 43                      181  NaN
# 203                     188  NaN
# 166                     187  NaN
#
#                  Осенний курс по выбору, приоритет 1  \
# 43                              Матричные вычисления
# 203  Сбор и обработка данных с помощью краудсорсинга
# 166                Высокопроизводительные вычисления
#
#                    Осенний курс по выбору, приоритет 2  \
# 43                                            Язык SQL
# 203  Принятие решений в условиях риска и неопределё...
# 166                   Безопасность компьютерных систем
#
#     Осенний курс по выбору, приоритет 3 Весенний курс по выбору, приоритет 1  \
# 43     Безопасность компьютерных систем                    Компьютерные сети
# 203   Высокопроизводительные вычисления                   Системы баз данных
# 166                            Язык SQL                    Компьютерные сети
#
#             Весенний курс по выбору, приоритет 2  \
# 43   Промышленное программирование на языке Java
# 203                             Численные методы
# 166  Промышленное программирование на языке Java
#
#     Весенний курс по выбору, приоритет 3 Вы заполняете анкету в первый раз?
# 43                    Системы баз данных                                 Да
# 203              Анализ данных в бизнесе                                 Да
# 166               Дискретная оптимизация                                 Да
#                 Timestamp                                ID Рейтинг  \
# 0 2020-05-15 01:12:50.543  93ff79a51cd602f1dd3028ba2c129503   704,0
# 1 2020-05-15 02:46:48.066  26b01b1c4cd5656bab18d24c548834fb   646,0
# 2 2020-05-15 03:12:41.480  30f3653fc176d54e89ac3179c455c6dd   624,0
#
#    Группа (в формате 182)  МИ? Осенний курс по выбору, приоритет 1  \
# 0                     181  NaN                            Язык SQL
# 1                     181  NaN   Высокопроизводительные вычисления
# 2                     185  NaN    Безопасность компьютерных систем
#
#   Осенний курс по выбору, приоритет 2 Осенний курс по выбору, приоритет 3  \
# 0   Высокопроизводительные вычисления                Матричные вычисления
# 1    Безопасность компьютерных систем                            Язык SQL
# 2                Матричные вычисления       Моделирование временных рядов
#
#   Весенний курс по выбору, приоритет 1 Весенний курс по выбору, приоритет 2  \
# 0               Дискретная оптимизация                     Численные методы
# 1               Дискретная оптимизация                     Численные методы
# 2               Дискретная оптимизация                  Машинное обучение 2
#
#   Весенний курс по выбору, приоритет 3 Вы заполняете анкету в первый раз?
# 0                  Машинное обучение 2                                 Да
# 1                  Машинное обучение 2                                Нет
# 2                     Численные методы                                 Да
# (None, None)

# %% [markdown]
# Если вам очень хочется отобразить все строки таблицы, то можно сделать так:

# %%
# pd.options.display.max_rows = 999
# data3

# %%
# pd.options.display.max_rows = 20

# %% [markdown]
# DataFrame, по сути, является двумерной таблицей с набором полезных методов. Давайте рассмотрим некоторые из них.
#
# ```columns``` — возвращает названия колонок
#
# ```dtypes``` — типы колонок

# %%
data3.columns
# Out:
# Index(['Timestamp', 'ID', 'Рейтинг', 'Группа (в формате 182)', 'МИ?',
#        'Осенний курс по выбору, приоритет 1',
#        'Осенний курс по выбору, приоритет 2',
#        'Осенний курс по выбору, приоритет 3',
#        'Весенний курс по выбору, приоритет 1',
#        'Весенний курс по выбору, приоритет 2',
#        'Весенний курс по выбору, приоритет 3',
#        'Вы заполняете анкету в первый раз?'],
#       dtype='object')

# %%
data3.dtypes
# Out:
# Timestamp                               datetime64[ns]
# ID                                              object
# Рейтинг                                         object
# Группа (в формате 182)                           int64
# МИ?                                            float64
# Осенний курс по выбору, приоритет 1             object
# Осенний курс по выбору, приоритет 2             object
# Осенний курс по выбору, приоритет 3             object
# Весенний курс по выбору, приоритет 1            object
# Весенний курс по выбору, приоритет 2            object
# Весенний курс по выбору, приоритет 3            object
# Вы заполняете анкету в первый раз?              object
# dtype: object

# %% [markdown]
# В DataFrame есть несколько способов для обращения к строкам, столбцам и отдельным элементам таблицы: квадратные скобки и методы ```loc```, ```iloc```.
#
# Как обычно, лучший источник знаний об этом — [документация](https://pandas.pydata.org/docs/user_guide/indexing.html).
# Ниже краткое содержание.

# %% [markdown]
# В метод ```loc``` можно передать значение индекса (число, которое стоит в колонке index) строки, чтобы получить эту строку:

# %%
data3.head(5)
# Out:
#                 Timestamp                                ID Рейтинг  \
# 0 2020-05-15 01:12:50.543  93ff79a51cd602f1dd3028ba2c129503   704,0
# 1 2020-05-15 02:46:48.066  26b01b1c4cd5656bab18d24c548834fb   646,0
# 2 2020-05-15 03:12:41.480  30f3653fc176d54e89ac3179c455c6dd   624,0
# 3 2020-05-15 04:43:08.994  1528f0eaa027580820ccf0d92a53ad68   579,0
# 4 2020-05-15 07:47:17.197  496ea4f0d4abe264b1bb1b80eb3830c5   632,0
#
#    Группа (в формате 182)  МИ? Осенний курс по выбору, приоритет 1  \
# 0                     181  NaN                            Язык SQL
# 1                     181  NaN   Высокопроизводительные вычисления
# 2                     185  NaN    Безопасность компьютерных систем
# 3                     182  NaN         Statistical Learning Theory
# 4                     183  NaN   Высокопроизводительные вычисления
#
#   Осенний курс по выбору, приоритет 2 Осенний курс по выбору, приоритет 3  \
# 0   Высокопроизводительные вычисления                Матричные вычисления
# 1    Безопасность компьютерных систем                            Язык SQL
# 2                Матричные вычисления       Моделирование временных рядов
# 3   Высокопроизводительные вычисления                Матричные вычисления
# 4    Безопасность компьютерных систем                   Теория баз данных
#
#   Весенний курс по выбору, приоритет 1 Весенний курс по выбору, приоритет 2  \
# 0               Дискретная оптимизация                     Численные методы
# 1               Дискретная оптимизация                     Численные методы
# 2               Дискретная оптимизация                  Машинное обучение 2
# 3               Дискретная оптимизация                     Численные методы
# 4                    Компьютерные сети               Дискретная оптимизация
#
#   Весенний курс по выбору, приоритет 3 Вы заполняете анкету в первый раз?
# 0                  Машинное обучение 2                                 Да
# 1                  Машинное обучение 2                                Нет
# 2                     Численные методы                                 Да
# 3                  Машинное обучение 2                                 Да
# 4                     Численные методы                                 Да

# %%
data3.loc[2]
# Out:
# Timestamp                                     2020-05-15 03:12:41.480000
# ID                                      30f3653fc176d54e89ac3179c455c6dd
# Рейтинг                                                            624,0
# Группа (в формате 182)                                               185
# МИ?                                                                  NaN
# Осенний курс по выбору, приоритет 1     Безопасность компьютерных систем
# Осенний курс по выбору, приоритет 2                 Матричные вычисления
# Осенний курс по выбору, приоритет 3        Моделирование временных рядов
# Весенний курс по выбору, приоритет 1              Дискретная оптимизация
# Весенний курс по выбору, приоритет 2                 Машинное обучение 2
# Весенний курс по выбору, приоритет 3                    Численные методы
# Вы заполняете анкету в первый раз?                                    Да
# Name: 2, dtype: object

# %% [markdown]
# Получили отдельную строчку в виде объекта класса [Series](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html):

# %%
type(data3.loc[2])
# Out:
# pandas.core.series.Series

# %% [markdown]
# А с помощью срезов можно выбрать часть таблицы:

# %%
data3.loc[20:25]
# Out:
#                  Timestamp                                ID Рейтинг  \
# 20 2020-05-15 21:55:16.699  f0f6f3881894172a0f04e79b554b49e6   676,0
# 21 2020-05-15 22:06:56.284  d3b992fe1016d7951d335db002d43dec   606,0
# 22 2020-05-15 22:15:31.902  a65d50ef4fadfac64508a54e972d8623   626,0
# 23 2020-05-15 22:30:31.902  a65d50ef4fadfac64508a54e972d8623   626,0
# 24 2020-05-15 22:41:51.724  cddf159101f9a5a30f9041ceebdb2835   650,0
# 25 2020-05-15 22:58:10.827  d82c2df25b8b36cd655077b4a885e1f7   617,0
#
#     Группа (в формате 182)  МИ? Осенний курс по выбору, приоритет 1  \
# 20                     181  NaN    Безопасность компьютерных систем
# 21                     183  NaN                Матричные вычисления
# 22                     184  NaN   Высокопроизводительные вычисления
# 23                     184  NaN    Безопасность компьютерных систем
# 24                     181  NaN    Безопасность компьютерных систем
# 25                     181  NaN                   Теория баз данных
#
#                 Осенний курс по выбору, приоритет 2  \
# 20  Сбор и обработка данных с помощью краудсорсинга
# 21                Высокопроизводительные вычисления
# 22                 Безопасность компьютерных систем
# 23                Высокопроизводительные вычисления
# 24                                Теория баз данных
# 25                 Безопасность компьютерных систем
#
#                   Осенний курс по выбору, приоритет 3  \
# 20  Принятие решений в условиях риска и неопределё...
# 21                   Безопасность компьютерных систем
# 22                               Матричные вычисления
# 23                               Матричные вычисления
# 24                                           Язык SQL
# 25                                           Язык SQL
#
#            Весенний курс по выбору, приоритет 1  \
# 20                          Машинное обучение 2
# 21                       Дискретная оптимизация
# 22                       Дискретная оптимизация
# 23                       Дискретная оптимизация
# 24                       Дискретная оптимизация
# 25  Промышленное программирование на языке Java
#
#    Весенний курс по выбору, приоритет 2  \
# 20                     Численные методы
# 21                     Численные методы
# 22                     Численные методы
# 23                     Численные методы
# 24                    Компьютерные сети
# 25                    Компьютерные сети
#
#           Весенний курс по выбору, приоритет 3  \
# 20  Дополнительные главы прикладной статистики
# 21                           Компьютерные сети
# 22                     Анализ данных в бизнесе
# 23                     Анализ данных в бизнесе
# 24                          Системы баз данных
# 25                      Дискретная оптимизация
#
#    Вы заполняете анкету в первый раз?
# 20                                 Да
# 21                                 Да
# 22                                 Да
# 23                                Нет
# 24                                 Да
# 25                                 Да

# %% [markdown]
# Срез в ```loc``` производится по index и включает в себя последний элемент.
#
# Метод ```iloc``` действует похожим образом, но он индексирует элементы не по index, а по порядку в таблице (который может отличаться от index). Например:

# %%
subset = data3.sample(5)
subset
# Out:
#                   Timestamp                                ID Рейтинг  \
# 111 2020-05-18 19:49:54.661  b3eb1cdc4beffbdd5b29a8d54d649bc0   731,0
# 53  2020-05-17 20:06:13.347  c3c0a0524bae841e5f9a56cf967cd423   667,0
# 31  2020-05-16 17:44:55.307  7df351e9f3a719f6c29e811e2578fcc6   637,0
# 204 2020-05-18 23:55:41.196  47e2d8bbb630bc2d9b3fbf98fe77cffb   631,0
# 198 2020-05-18 23:43:49.020  2b844a1be49f4ed2d578fb50b752883b   696,0
#
#      Группа (в формате 182)  МИ?  \
# 111                     185  NaN
# 53                      181  NaN
# 31                      188  NaN
# 204                     188  NaN
# 198                     184  NaN
#
#                  Осенний курс по выбору, приоритет 1  \
# 111                 Безопасность компьютерных систем
# 53                     Моделирование временных рядов
# 31                  Безопасность компьютерных систем
# 204  Сбор и обработка данных с помощью краудсорсинга
# 198                 Безопасность компьютерных систем
#
#     Осенний курс по выбору, приоритет 2  \
# 111                Матричные вычисления
# 53                             Язык SQL
# 31    Высокопроизводительные вычисления
# 204                            Язык SQL
# 198                Матричные вычисления
#
#                  Осенний курс по выбору, приоритет 3  \
# 111                    Моделирование временных рядов
# 53   Сбор и обработка данных с помощью краудсорсинга
# 31                                          Язык SQL
# 204                Высокопроизводительные вычисления
# 198                Высокопроизводительные вычисления
#
#             Весенний курс по выбору, приоритет 1  \
# 111  Промышленное программирование на языке Java
# 53   Промышленное программирование на языке Java
# 31                             Компьютерные сети
# 204                            Компьютерные сети
# 198   Дополнительные главы прикладной статистики
#
#             Весенний курс по выбору, приоритет 2  \
# 111                            Компьютерные сети
# 53                            Системы баз данных
# 31                            Системы баз данных
# 204  Промышленное программирование на языке Java
# 198                       Дискретная оптимизация
#
#             Весенний курс по выбору, приоритет 3  \
# 111                       Дискретная оптимизация
# 53                             Компьютерные сети
# 31                           Машинное обучение 2
# 204                          Машинное обучение 2
# 198  Промышленное программирование на языке Java
#
#     Вы заполняете анкету в первый раз?
# 111                                 Да
# 53                                  Да
# 31                                  Да
# 204                                Нет
# 198                                 Да

# %% [markdown]
# Если же вызвать просто ```loc[2]```, то получим ошибку:

# %%
# subset.loc[2] # вот это выдаст ошибку

# %% [markdown]
# С помощью ```iloc``` тоже можно делать срезы, но в них последний элемент не включается (как и в обычных срезах в Python, **в отличие от loc**):

# %%
subset.iloc[2:4]
# Out:
#                   Timestamp                                ID Рейтинг  \
# 31  2020-05-16 17:44:55.307  7df351e9f3a719f6c29e811e2578fcc6   637,0
# 204 2020-05-18 23:55:41.196  47e2d8bbb630bc2d9b3fbf98fe77cffb   631,0
#
#      Группа (в формате 182)  МИ?  \
# 31                      188  NaN
# 204                     188  NaN
#
#                  Осенний курс по выбору, приоритет 1  \
# 31                  Безопасность компьютерных систем
# 204  Сбор и обработка данных с помощью краудсорсинга
#
#     Осенний курс по выбору, приоритет 2 Осенний курс по выбору, приоритет 3  \
# 31    Высокопроизводительные вычисления                            Язык SQL
# 204                            Язык SQL   Высокопроизводительные вычисления
#
#     Весенний курс по выбору, приоритет 1  \
# 31                     Компьютерные сети
# 204                    Компьютерные сети
#
#             Весенний курс по выбору, приоритет 2  \
# 31                            Системы баз данных
# 204  Промышленное программирование на языке Java
#
#     Весенний курс по выбору, приоритет 3 Вы заполняете анкету в первый раз?
# 31                   Машинное обучение 2                                 Да
# 204                  Машинное обучение 2                                Нет

# %% [markdown]
# Срезы можно брать не только по строкам, но и по столбцам. Обратите внимание на различия индексации столбцов в ```loc``` и ```iloc```:

# %%
data3.iloc[1:4, 2:6]
# Out:
#   Рейтинг  Группа (в формате 182)  МИ? Осенний курс по выбору, приоритет 1
# 1   646,0                     181  NaN   Высокопроизводительные вычисления
# 2   624,0                     185  NaN    Безопасность компьютерных систем
# 3   579,0                     182  NaN         Statistical Learning Theory

# %%
data3.loc[1:4, 'Рейтинг':'Осенний курс по выбору, приоритет 1']
# Out:
#   Рейтинг  Группа (в формате 182)  МИ? Осенний курс по выбору, приоритет 1
# 1   646,0                     181  NaN   Высокопроизводительные вычисления
# 2   624,0                     185  NaN    Безопасность компьютерных систем
# 3   579,0                     182  NaN         Statistical Learning Theory
# 4   632,0                     183  NaN   Высокопроизводительные вычисления

# %% [markdown]
# Через квадратные скобки можно обращаться к одной или нескольким колонкам:

# %%
data3[['Рейтинг', 'Осенний курс по выбору, приоритет 1']].head(3)
# Out:
#   Рейтинг Осенний курс по выбору, приоритет 1
# 0   704,0                            Язык SQL
# 1   646,0   Высокопроизводительные вычисления
# 2   624,0    Безопасность компьютерных систем

# %% [markdown]
# Есть и более интересные способы индексации. Например, давайте выберем студентов из группы 182:

# %%
data3[data3['Группа (в формате 182)'] == 182].sample(3)
# Out:
#                  Timestamp                                ID Рейтинг  \
# 26 2020-05-15 22:59:40.602  a0c56e8aa03ea6c1f5e8462914472075   750,0
# 83 2020-05-18 17:21:14.354  7f9d0f835bf734ccd4619041c3475c1c   688,0
# 89 2020-05-18 18:01:52.604  fd784637a19d65bbe5b07d6efac5a05d   624,0
#
#     Группа (в формате 182)  МИ?  \
# 26                     182  NaN
# 83                     182  NaN
# 89                     182  NaN
#
#                 Осенний курс по выбору, приоритет 1  \
# 26  Сбор и обработка данных с помощью краудсорсинга
# 83                 Безопасность компьютерных систем
# 89                 Безопасность компьютерных систем
#
#    Осенний курс по выбору, приоритет 2 Осенний курс по выбору, приоритет 3  \
# 26         Statistical Learning Theory       Моделирование временных рядов
# 83         Statistical Learning Theory                Матричные вычисления
# 89         Statistical Learning Theory                Матричные вычисления
#
#           Весенний курс по выбору, приоритет 1  \
# 26  Дополнительные главы прикладной статистики
# 83                      Дискретная оптимизация
# 89                         Машинное обучение 2
#
#           Весенний курс по выбору, приоритет 2  \
# 26                      Дискретная оптимизация
# 83  Дополнительные главы прикладной статистики
# 89                      Дискретная оптимизация
#
#            Весенний курс по выбору, приоритет 3  \
# 26                             Численные методы
# 83  Промышленное программирование на языке Java
# 89                            Компьютерные сети
#
#    Вы заполняете анкету в первый раз?
# 26                                 Да
# 83                                Нет
# 89                                 Да

# %% [markdown]
# С DataFrame'ами и Series'ами одинаковой структуры можно производить математические операции:

# %%
data3.head(3)
# Out:
#                 Timestamp                                ID Рейтинг  \
# 0 2020-05-15 01:12:50.543  93ff79a51cd602f1dd3028ba2c129503   704,0
# 1 2020-05-15 02:46:48.066  26b01b1c4cd5656bab18d24c548834fb   646,0
# 2 2020-05-15 03:12:41.480  30f3653fc176d54e89ac3179c455c6dd   624,0
#
#    Группа (в формате 182)  МИ? Осенний курс по выбору, приоритет 1  \
# 0                     181  NaN                            Язык SQL
# 1                     181  NaN   Высокопроизводительные вычисления
# 2                     185  NaN    Безопасность компьютерных систем
#
#   Осенний курс по выбору, приоритет 2 Осенний курс по выбору, приоритет 3  \
# 0   Высокопроизводительные вычисления                Матричные вычисления
# 1    Безопасность компьютерных систем                            Язык SQL
# 2                Матричные вычисления       Моделирование временных рядов
#
#   Весенний курс по выбору, приоритет 1 Весенний курс по выбору, приоритет 2  \
# 0               Дискретная оптимизация                     Численные методы
# 1               Дискретная оптимизация                     Численные методы
# 2               Дискретная оптимизация                  Машинное обучение 2
#
#   Весенний курс по выбору, приоритет 3 Вы заполняете анкету в первый раз?
# 0                  Машинное обучение 2                                 Да
# 1                  Машинное обучение 2                                Нет
# 2                     Численные методы                                 Да

# %%
strange_feature = data3['Рейтинг'] ** 2 + data3['Группа (в формате 182)']
strange_feature.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     217     try:
# --> 218         result = func(left, right)
#     219     except TypeError:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     241             # error: "None" not callable
# --> 242             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243     return _evaluate_standard(op, op_str, a, b)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     130     if result is None:
# --> 131         result = _evaluate_standard(op, op_str, a, b)
#     132
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b)
#      72         _store_test_result(False)
# ---> 73     return op(a, b)
#      74
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-20aa5712af36> in <cell line: 1>()
# ----> 1 strange_feature = data3['Рейтинг'] ** 2 + data3['Группа (в формате 182)']
#       2 strange_feature.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#      77
#      78     return new_method
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py in __pow__(self, other)
#     240     @unpack_zerodim_and_defer("__pow__")
#     241     def __pow__(self, other):
# --> 242         return self._arith_method(other, operator.pow)
#     243
#     244     @unpack_zerodim_and_defer("__rpow__")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _arith_method(self, other, op)
#    6133     def _arith_method(self, other, op):
#    6134         self, other = self._align_for_op(other)
# -> 6135         return base.IndexOpsMixin._arith_method(self, other, op)
#    6136
#    6137     def _align_for_op(self, right, align_asobject: bool = False):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/base.py in _arith_method(self, other, op)
#    1380
#    1381         with np.errstate(all="ignore"):
# -> 1382             result = ops.arithmetic_op(lvalues, rvalues, op)
#    1383
#    1384         return self._construct_result(result, name=res_name)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/array_ops.py in arithmetic_op(left, right, op)
#     281         # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     282         # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 283         res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     284
#     285     return res_values
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     225             # Don't do this for comparisons, as that will handle complex numbers
#     226             #  incorrectly, see GH#32047
# --> 227             result = _masked_arith_op(left, right, op)
#     228         else:
#     229             raise
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/array_ops.py in _masked_arith_op(x, y, op)
#     180
#     181         if mask.any():
# --> 182             result[mask] = op(xrav[mask], y)
#     183
#     184     np.putmask(result, ~mask, np.nan)
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'

# %%
data3['Рейтинг'].head(3)
# Out:
# 0    704,0
# 1    646,0
# 2    624,0
# Name: Рейтинг, dtype: object

# %% [markdown]
# Видимо, 'Рейтинг' представлен в виде строки. Исправим это:

# %%
data3['Рейтинг'].apply(lambda x: float(str(x).replace(',', '.')))

strange_feature = data3['Рейтинг'] ** 2 + data3['Группа (в формате 182)']
strange_feature.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     217     try:
# --> 218         result = func(left, right)
#     219     except TypeError:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     241             # error: "None" not callable
# --> 242             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243     return _evaluate_standard(op, op_str, a, b)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     130     if result is None:
# --> 131         result = _evaluate_standard(op, op_str, a, b)
#     132
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b)
#      72         _store_test_result(False)
# ---> 73     return op(a, b)
#      74
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-5c625f16793b> in <cell line: 3>()
#       1 data3['Рейтинг'].apply(lambda x: float(str(x).replace(',', '.')))
#       2
# ----> 3 strange_feature = data3['Рейтинг'] ** 2 + data3['Группа (в формате 182)']
#       4 strange_feature.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#      77
#      78     return new_method
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py in __pow__(self, other)
#     240     @unpack_zerodim_and_defer("__pow__")
#     241     def __pow__(self, other):
# --> 242         return self._arith_method(other, operator.pow)
#     243
#     244     @unpack_zerodim_and_defer("__rpow__")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _arith_method(self, other, op)
#    6133     def _arith_method(self, other, op):
#    6134         self, other = self._align_for_op(other)
# -> 6135         return base.IndexOpsMixin._arith_method(self, other, op)
#    6136
#    6137     def _align_for_op(self, right, align_asobject: bool = False):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/base.py in _arith_method(self, other, op)
#    1380
#    1381         with np.errstate(all="ignore"):
# -> 1382             result = ops.arithmetic_op(lvalues, rvalues, op)
#    1383
#    1384         return self._construct_result(result, name=res_name)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/array_ops.py in arithmetic_op(left, right, op)
#     281         # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     282         # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 283         res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     284
#     285     return res_values
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     225             # Don't do this for comparisons, as that will handle complex numbers
#     226             #  incorrectly, see GH#32047
# --> 227             result = _masked_arith_op(left, right, op)
#     228         else:
#     229             raise
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/array_ops.py in _masked_arith_op(x, y, op)
#     180
#     181         if mask.any():
# --> 182             result[mask] = op(xrav[mask], y)
#     183
#     184     np.putmask(result, ~mask, np.nan)
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'

# %% [markdown]
# Получаем ту же ошибку, ведь метод apply не модифицирует таблицу, а просто возвращает новый столбец. Обходят это обычно так:

# %%
data3['Рейтинг'] = data3['Рейтинг'].apply(lambda x: float(x.replace(',', '.')))

strange_feature = data3['Рейтинг'] ** 2 + data3['Группа (в формате 182)']
strange_feature.head()
# Out:
# 0    495797.0
# 1    417497.0
# 2    389561.0
# 3    335423.0
# 4    399607.0
# dtype: float64

# %% [markdown]
# В дальнейшем нам понадобится работать с перцентилями студентов. Чтобы сделать такой столбец, в pandas уже есть подходящий метод:

# %%
# Что делает функция rank(): https://www.w3resource.com/pandas/dataframe/dataframe-rank.php
# перцентиль = сколько студентов имеют результаты лучше, чем у этого студента
data3['percentile'] = 1 - data3['Рейтинг'].rank() / data3.shape[0]

# добавим также наш странный признак
data3['new'] = strange_feature

# %% [markdown]
# При желании можно удалить любой признак при помоши метода ```drop```:

# %%
data3 = data3.drop(columns=['new'])
data3.head()
# Out:
#                 Timestamp                                ID  Рейтинг  \
# 0 2020-05-15 01:12:50.543  93ff79a51cd602f1dd3028ba2c129503    704.0
# 1 2020-05-15 02:46:48.066  26b01b1c4cd5656bab18d24c548834fb    646.0
# 2 2020-05-15 03:12:41.480  30f3653fc176d54e89ac3179c455c6dd    624.0
# 3 2020-05-15 04:43:08.994  1528f0eaa027580820ccf0d92a53ad68    579.0
# 4 2020-05-15 07:47:17.197  496ea4f0d4abe264b1bb1b80eb3830c5    632.0
#
#    Группа (в формате 182)  МИ? Осенний курс по выбору, приоритет 1  \
# 0                     181  NaN                            Язык SQL
# 1                     181  NaN   Высокопроизводительные вычисления
# 2                     185  NaN    Безопасность компьютерных систем
# 3                     182  NaN         Statistical Learning Theory
# 4                     183  NaN   Высокопроизводительные вычисления
#
#   Осенний курс по выбору, приоритет 2 Осенний курс по выбору, приоритет 3  \
# 0   Высокопроизводительные вычисления                Матричные вычисления
# 1    Безопасность компьютерных систем                            Язык SQL
# 2                Матричные вычисления       Моделирование временных рядов
# 3   Высокопроизводительные вычисления                Матричные вычисления
# 4    Безопасность компьютерных систем                   Теория баз данных
#
#   Весенний курс по выбору, приоритет 1 Весенний курс по выбору, приоритет 2  \
# 0               Дискретная оптимизация                     Численные методы
# 1               Дискретная оптимизация                     Численные методы
# 2               Дискретная оптимизация                  Машинное обучение 2
# 3               Дискретная оптимизация                     Численные методы
# 4                    Компьютерные сети               Дискретная оптимизация
#
#   Весенний курс по выбору, приоритет 3 Вы заполняете анкету в первый раз?  \
# 0                  Машинное обучение 2                                 Да
# 1                  Машинное обучение 2                                Нет
# 2                     Численные методы                                 Да
# 3                  Машинное обучение 2                                 Да
# 4                     Численные методы                                 Да
#
#    percentile
# 0    0.179372
# 1    0.504484
# 2    0.679372
# 3    0.876682
# 4    0.598655

# %% [markdown]
# ### Разведочный анализ
#
# Теперь изучим наши данные. Вашим домашним заданием будет распределение студентов по курсам, с учётом их предпочтений, рейтинга и ограничений. Начнём к этому готовиться.

# %% [markdown]
# Для начала посмотрим еще раз на типы данных и подумаем, надо ли их менять:

# %%
data3.dtypes
# Out:
# Timestamp                               datetime64[ns]
# ID                                              object
# Рейтинг                                        float64
# Группа (в формате 182)                           int64
# МИ?                                            float64
# Осенний курс по выбору, приоритет 1             object
# Осенний курс по выбору, приоритет 2             object
# Осенний курс по выбору, приоритет 3             object
# Весенний курс по выбору, приоритет 1            object
# Весенний курс по выбору, приоритет 2            object
# Весенний курс по выбору, приоритет 3            object
# Вы заполняете анкету в первый раз?              object
# percentile                                     float64
# dtype: object

# %% [markdown]
# Вроде бы нет...
#
# А что с таблицей для 4ого курса? Как вы знаете, на ряд курсов студенты 3 и 4 годов обучения отбираются совместно, поэтому надо собрать данные в одну таблицу. *Можно ли это сделать без подготовки?*

# %%
data3.head()
# Out:
#                 Timestamp                                ID  Рейтинг  \
# 0 2020-05-15 01:12:50.543  93ff79a51cd602f1dd3028ba2c129503    704.0
# 1 2020-05-15 02:46:48.066  26b01b1c4cd5656bab18d24c548834fb    646.0
# 2 2020-05-15 03:12:41.480  30f3653fc176d54e89ac3179c455c6dd    624.0
# 3 2020-05-15 04:43:08.994  1528f0eaa027580820ccf0d92a53ad68    579.0
# 4 2020-05-15 07:47:17.197  496ea4f0d4abe264b1bb1b80eb3830c5    632.0
#
#    Группа (в формате 182)  МИ? Осенний курс по выбору, приоритет 1  \
# 0                     181  NaN                            Язык SQL
# 1                     181  NaN   Высокопроизводительные вычисления
# 2                     185  NaN    Безопасность компьютерных систем
# 3                     182  NaN         Statistical Learning Theory
# 4                     183  NaN   Высокопроизводительные вычисления
#
#   Осенний курс по выбору, приоритет 2 Осенний курс по выбору, приоритет 3  \
# 0   Высокопроизводительные вычисления                Матричные вычисления
# 1    Безопасность компьютерных систем                            Язык SQL
# 2                Матричные вычисления       Моделирование временных рядов
# 3   Высокопроизводительные вычисления                Матричные вычисления
# 4    Безопасность компьютерных систем                   Теория баз данных
#
#   Весенний курс по выбору, приоритет 1 Весенний курс по выбору, приоритет 2  \
# 0               Дискретная оптимизация                     Численные методы
# 1               Дискретная оптимизация                     Численные методы
# 2               Дискретная оптимизация                  Машинное обучение 2
# 3               Дискретная оптимизация                     Численные методы
# 4                    Компьютерные сети               Дискретная оптимизация
#
#   Весенний курс по выбору, приоритет 3 Вы заполняете анкету в первый раз?  \
# 0                  Машинное обучение 2                                 Да
# 1                  Машинное обучение 2                                Нет
# 2                     Численные методы                                 Да
# 3                  Машинное обучение 2                                 Да
# 4                     Численные методы                                 Да
#
#    percentile
# 0    0.179372
# 1    0.504484
# 2    0.679372
# 3    0.876682
# 4    0.598655

# %%
data4.head()
# Out:
#                 Timestamp                                ID Рейтинг  \
# 0 2020-05-14 20:23:21.662  d555d2805e1d93d4f023e57dc4c8f403   995,0
# 1 2020-05-14 20:47:13.833  253bbe1a2021d0404712a1e4acd22939  1105,0
# 2 2020-05-14 20:52:42.734  881b1a6fda195b354ae2edb396a69f5d  1083,0
# 3 2020-05-14 21:03:02.916  5a9b8ac11ad05b39a58b0e04a263bf4c  1169,0
# 4 2020-05-14 21:10:54.945  1bbbfae51794b83c769b634be8da7b8d  1077,0
#
#    Группа (в формате 173) blended-курс   Осенний курс по выбору, приоритет 1  \
# 0                     172       DevOps      Безопасность компьютерных систем
# 1                     176       DevOps      Безопасность компьютерных систем
# 2                     172       DevOps      Безопасность компьютерных систем
# 3                     171       DevOps  Глубинное обучение в обработке звука
# 4                     176       DevOps      Безопасность компьютерных систем
#
#     Осенний курс по выбору, приоритет 2  \
# 0  Глубинное обучение в обработке звука
# 1         Моделирование временных рядов
# 2     Анализ неструктурированных данных
# 3           Statistical Learning Theory
# 4     Высокопроизводительные вычисления
#
#                Осенний курс по выбору, приоритет 3  \
# 0            Байесовские методы машинного обучения
# 1                      Statistical Learning Theory
# 2             Глубинное обучение в обработке звука
# 3  Сбор и обработка данных с помощью краудсорсинга
# 4                Анализ неструктурированных данных
#
#                 Весенний курс по выбору, приоритет 1  \
# 0                                Компьютерное зрение
# 1  Проектирование и разработка высоконагруженных ...
# 2                                Компьютерное зрение
# 3                             Конфликты и кооперация
# 4  Проектирование и разработка высоконагруженных ...
#
#                 Весенний курс по выбору, приоритет 2  \
# 0                           Обучение с подкреплением
# 1                                   Численные методы
# 2  Проектирование и разработка высоконагруженных ...
# 3                           Обучение с подкреплением
# 4               Методы сжатия и передачи медиаданных
#
#                 Весенний курс по выбору, приоритет 3  \
# 0  Проектирование и разработка высоконагруженных ...
# 1               Методы сжатия и передачи медиаданных
# 2            Генеративные модели в машинном обучении
# 3            Генеративные модели в машинном обучении
# 4                             Конфликты и кооперация
#
#   Вы заполняете анкету в первый раз?
# 0                                 Да
# 1                                 Да
# 2                                 Да
# 3                                 Да
# 4                                 Да

# %% [markdown]
# Кажется, рейтинги имеют разные распределения. Проверим это:

# %%
data3['Рейтинг'].describe()
# Out:
# count    223.000000
# mean     648.816143
# std       58.255552
# min      495.000000
# 25%      609.000000
# 50%      647.000000
# 75%      691.000000
# max      784.000000
# Name: Рейтинг, dtype: float64

# %% [markdown]
# Да, рейтинг для 4 курса тоже надо привести к числовому типу.

# %%
data4['Рейтинг'] = data4['Рейтинг'].apply(lambda x: float(str(x).replace(',', '.')))
data4['Рейтинг'].describe()
# Out:
# count     138.000000
# mean     1155.188406
# std        91.659203
# min       963.000000
# 25%      1086.500000
# 50%      1155.500000
# 75%      1217.500000
# max      1456.000000
# Name: Рейтинг, dtype: float64

# %% [markdown]
# Видно, что квантили в самом деле отличаются — поэтому сами рейтинги не стоит использовать после объединения таблиц, надо работать только с перцентилями. Вычислим их и объединим таблицы с помощью метода ```concat```:

# %%
data4['percentile'] = 1 - data4['Рейтинг'].rank() / data4.shape[0]

data = pd.concat([data3, data4])
data.head()
# Out:
#                 Timestamp                                ID  Рейтинг  \
# 0 2020-05-15 01:12:50.543  93ff79a51cd602f1dd3028ba2c129503    704.0
# 1 2020-05-15 02:46:48.066  26b01b1c4cd5656bab18d24c548834fb    646.0
# 2 2020-05-15 03:12:41.480  30f3653fc176d54e89ac3179c455c6dd    624.0
# 3 2020-05-15 04:43:08.994  1528f0eaa027580820ccf0d92a53ad68    579.0
# 4 2020-05-15 07:47:17.197  496ea4f0d4abe264b1bb1b80eb3830c5    632.0
#
#    Группа (в формате 182)  МИ? Осенний курс по выбору, приоритет 1  \
# 0                   181.0  NaN                            Язык SQL
# 1                   181.0  NaN   Высокопроизводительные вычисления
# 2                   185.0  NaN    Безопасность компьютерных систем
# 3                   182.0  NaN         Statistical Learning Theory
# 4                   183.0  NaN   Высокопроизводительные вычисления
#
#   Осенний курс по выбору, приоритет 2 Осенний курс по выбору, приоритет 3  \
# 0   Высокопроизводительные вычисления                Матричные вычисления
# 1    Безопасность компьютерных систем                            Язык SQL
# 2                Матричные вычисления       Моделирование временных рядов
# 3   Высокопроизводительные вычисления                Матричные вычисления
# 4    Безопасность компьютерных систем                   Теория баз данных
#
#   Весенний курс по выбору, приоритет 1 Весенний курс по выбору, приоритет 2  \
# 0               Дискретная оптимизация                     Численные методы
# 1               Дискретная оптимизация                     Численные методы
# 2               Дискретная оптимизация                  Машинное обучение 2
# 3               Дискретная оптимизация                     Численные методы
# 4                    Компьютерные сети               Дискретная оптимизация
#
#   Весенний курс по выбору, приоритет 3 Вы заполняете анкету в первый раз?  \
# 0                  Машинное обучение 2                                 Да
# 1                  Машинное обучение 2                                Нет
# 2                     Численные методы                                 Да
# 3                  Машинное обучение 2                                 Да
# 4                     Численные методы                                 Да
#
#    percentile  Группа (в формате 173) blended-курс
# 0    0.179372                     NaN          NaN
# 1    0.504484                     NaN          NaN
# 2    0.679372                     NaN          NaN
# 3    0.876682                     NaN          NaN
# 4    0.598655                     NaN          NaN

# %% [markdown]
# Теперь для удобства переименуем столбцы (обратите внимание на ```inplace=True```):

# %%
data.rename(columns={'Timestamp':'timestamp',
                     'ID':'id',
                     'Рейтинг':'rating',
                     'МИ?':'is_mi',
                     'Группа (в формате 182)':'18_group',
                     'Группа (в формате 173)':'17_group',
                     'Осенний курс по выбору, приоритет 1':'fall_1',
                     'Осенний курс по выбору, приоритет 2':'fall_2',
                     'Осенний курс по выбору, приоритет 3':'fall_3',
                     'Весенний курс по выбору, приоритет 1':'spring_1',
                     'Весенний курс по выбору, приоритет 2':'spring_2',
                     'Весенний курс по выбору, приоритет 3':'spring_3',
                     'Вы заполняете анкету в первый раз?':'is_first_time',
                     'blended-курс':'blended'},
           inplace=True)

# %% [markdown]
# Поскольку у (почти всех) столбцов теперь названия являются корректными именами переменных в Python, мы можем использовать ещё один способ обращения к столбцам таблицы как к полям класса:

# %%
data
# Out:
#                   timestamp                                id  rating  \
# 0   2020-05-15 01:12:50.543  93ff79a51cd602f1dd3028ba2c129503   704.0
# 27      182.0    NaN    Сбор и обработка данных с помощью краудсорсинга
# 28      186.0    NaN    Сбор и обработка данных с помощью краудсорсинга
# 29      185.0    NaN                                  Теория баз данных
# 30      185.0    NaN                   Безопасность компьютерных систем
# 31      188.0    NaN                   Безопасность компьютерных систем
# 32      187.0    NaN                                           Язык SQL
# 33      183.0    NaN                               Матричные вычисления
# 34      187.0    NaN                                           Язык SQL
# 35      182.0    1.0                        Statistical Learning Theory
# 36      184.0    NaN                   Безопасность компьютерных систем
# 37      186.0    NaN                   Безопасность компьютерных систем
# 38      181.0    NaN                   Безопасность компьютерных систем
# 39      187.0    NaN                                           Язык SQL
# 40      187.0    NaN                   Безопасность компьютерных систем
# 41      185.0    NaN                   Безопасность компьютерных систем
# 42      187.0    NaN                        Statistical Learning Theory
# 43      181.0    NaN                               Матричные вычисления
# 44      184.0    1.0                   Безопасность компьютерных систем
# 45      185.0    NaN                               Матричные вычисления
# 46      186.0    NaN    Сбор и обработка данных с помощью краудсорсинга
# 47      184.0    NaN                   Безопасность компьютерных систем
# 48      182.0    NaN                   Безопасность компьютерных систем
# 49      185.0    NaN                                  Теория баз данных
# 50      188.0    NaN                   Безопасность компьютерных систем
# 51      182.0    NaN                      Моделирование временных рядов
# 52      183.0    NaN    Сбор и обработка данных с помощью краудсорсинга
# 53      181.0    NaN                      Моделирование временных рядов
# 54      182.0    NaN                               Матричные вычисления
# 55      181.0    NaN                               Матричные вычисления
# 56      184.0    NaN                   Безопасность компьютерных систем
# 57      188.0    NaN                   Безопасность компьютерных систем
# 58      184.0    NaN                   Безопасность компьютерных систем
# 59      185.0    NaN                   Безопасность компьютерных систем
# 60      183.0    NaN                               Матричные вычисления
# 61      186.0    NaN                      Моделирование временных рядов
# 62      188.0    NaN                   Безопасность компьютерных систем
# 63      186.0    NaN    Сбор и обработка данных с помощью краудсорсинга
# 64      183.0    NaN                   Безопасность компьютерных систем
# 65      184.0    NaN                      Моделирование временных рядов
# 66      187.0    NaN                                           Язык SQL
# 67      186.0    NaN                      Моделирование временных рядов
# 68      182.0    NaN                   Безопасность компьютерных систем
# 69      181.0    NaN    Сбор и обработка данных с помощью краудсорсинга
# 70      186.0    NaN                               Матричные вычисления
# 71      185.0    1.0                               Матричные вычисления
# 72      187.0    NaN                   Безопасность компьютерных систем
# 73      185.0    NaN                                  Теория баз данных
# 74      186.0    NaN    Сбор и обработка данных с помощью краудсорсинга
# 75      182.0    NaN                   Безопасность компьютерных систем
# 76      186.0    NaN    Сбор и обработка данных с помощью краудсорсинга
# 77      181.0    NaN                               Матричные вычисления
# 78      181.0    NaN                   Безопасность компьютерных систем
# 79      186.0    1.0                                           Язык SQL
# 80      182.0    NaN                   Безопасность компьютерных систем
# 81      188.0    1.0    Сбор и обработка данных с помощью краудсорсинга
# 82      186.0    NaN                   Безопасность компьютерных систем
# 83      182.0    NaN                   Безопасность компьютерных систем
# 84      182.0    NaN                   Безопасность компьютерных систем
# 85      182.0    NaN                                  Теория баз данных
# 86      187.0    NaN                   Безопасность компьютерных систем
# 87      187.0    NaN                        Statistical Learning Theory
# 88      182.0    NaN                   Безопасность компьютерных систем
# 89      182.0    NaN                   Безопасность компьютерных систем
# 90      186.0    NaN                   Безопасность компьютерных систем
# 91      182.0    NaN                               Матричные вычисления
# 92      184.0    NaN                        Statistical Learning Theory
# 93      181.0    NaN                        Statistical Learning Theory
# 94      182.0    NaN    Сбор и обработка данных с помощью краудсорсинга
# 95      188.0    NaN                        Statistical Learning Theory
# 96      181.0    NaN                   Безопасность компьютерных систем
# 97      185.0    NaN                                           Язык SQL
# 98      185.0    NaN                   Безопасность компьютерных систем
# 99      185.0    NaN                   Безопасность компьютерных систем
# 100     184.0    NaN                   Безопасность компьютерных систем
# 101     186.0    NaN                  Высокопроизводительные вычисления
# 102     185.0    NaN                   Безопасность компьютерных систем
# 103     182.0    NaN                      Моделирование временных рядов
# 104     186.0    NaN                   Безопасность компьютерных систем
# 105     186.0    NaN                      Моделирование временных рядов
# 106     185.0    NaN                   Безопасность компьютерных систем
# 107     184.0    NaN                        Statistical Learning Theory
# 108     187.0    NaN    Сбор и обработка данных с помощью краудсорсинга
# 109     187.0    NaN                               Матричные вычисления
# 110     187.0    NaN    Сбор и обработка данных с помощью краудсорсинга
# 111     185.0    NaN                   Безопасность компьютерных систем
# 112     185.0    NaN  Принятие решений в условиях риска и неопределё...
# 113     187.0    NaN                   Безопасность компьютерных систем
# 114     183.0    NaN                                           Язык SQL
# 115     186.0    NaN                                           Язык SQL
# 116     187.0    NaN                  Высокопроизводительные вычисления
# 117     183.0    NaN                      Моделирование временных рядов
# 118     185.0    NaN                   Безопасность компьютерных систем
# 119     183.0    NaN                                           Язык SQL
# 120     184.0    NaN                                  Теория баз данных
# 121     183.0    NaN                                           Язык SQL
# 122     184.0    1.0                      Моделирование временных рядов
# 123     185.0    NaN                   Безопасность компьютерных систем
# 124     184.0    NaN                                  Теория баз данных
# 125     181.0    NaN                  Высокопроизводительные вычисления
# 126     183.0    NaN                   Безопасность компьютерных систем
# 127     183.0    NaN                      Моделирование временных рядов
# 128     187.0    NaN                   Безопасность компьютерных систем
# 129     187.0    NaN    Сбор и обработка данных с помощью краудсорсинга
# 130     187.0    NaN                   Безопасность компьютерных систем
# 131     188.0    NaN                   Безопасность компьютерных систем
# 132     185.0    NaN                                           Язык SQL
# 133     185.0    NaN                   Безопасность компьютерных систем
# 134     182.0    NaN                   Безопасность компьютерных систем
# 135     186.0    1.0                   Безопасность компьютерных систем
# 136     187.0    1.0                      Моделирование временных рядов
# 137     187.0    NaN                      Моделирование временных рядов
# 138     187.0    NaN    Сбор и обработка данных с помощью краудсорсинга
# 139     187.0    NaN                               Матричные вычисления
# 140     183.0    NaN                   Безопасность компьютерных систем
# 141     185.0    1.0                                  Теория баз данных
# 142     188.0    NaN                      Моделирование временных рядов
# 143     185.0    NaN                  Высокопроизводительные вычисления
# 144     188.0    1.0                      Моделирование временных рядов
# 145     187.0    NaN                   Безопасность компьютерных систем
# 146     183.0    NaN                                           Язык SQL
# 147     188.0    NaN                                           Язык SQL
# 148     188.0    1.0                      Моделирование временных рядов
# 149     188.0    NaN                                           Язык SQL
# 150     185.0    1.0                      Моделирование временных рядов
# 151     182.0    NaN                   Безопасность компьютерных систем
# 152     188.0    1.0                                           Язык SQL
# 153     182.0    NaN                   Безопасность компьютерных систем
# 154     184.0    NaN                   Безопасность компьютерных систем
# 155     184.0    NaN                                  Теория баз данных
# 156     186.0    NaN    Сбор и обработка данных с помощью краудсорсинга
# 157     183.0    NaN                  Высокопроизводительные вычисления
# 158     184.0    NaN                        Statistical Learning Theory
# 159     181.0    NaN                   Безопасность компьютерных систем
# 160     183.0    NaN                      Моделирование временных рядов
# 161     187.0    NaN                   Безопасность компьютерных систем
# 162     188.0    NaN                                           Язык SQL
# 163     186.0    NaN                  Высокопроизводительные вычисления
# 164     186.0    NaN    Сбор и обработка данных с помощью краудсорсинга
# 165     188.0    1.0                      Моделирование временных рядов
# 166     187.0    NaN                  Высокопроизводительные вычисления
# 167     185.0    NaN    Сбор и обработка данных с помощью краудсорсинга
# 168     183.0    NaN                                           Язык SQL
# 169     187.0    NaN                   Безопасность компьютерных систем
# 170     188.0    NaN                   Безопасность компьютерных систем
# 171     183.0    NaN                   Безопасность компьютерных систем
# 172     185.0    NaN                      Моделирование временных рядов
# 173     185.0    NaN                   Безопасность компьютерных систем
# 174     187.0    NaN                                           Язык SQL
# 175     183.0    NaN                  Высокопроизводительные вычисления
# 176     187.0    NaN                   Безопасность компьютерных систем
# 177     186.0    NaN    Сбор и обработка данных с помощью краудсорсинга
# 178     183.0    NaN                   Безопасность компьютерных систем
# 179     183.0    NaN                      Моделирование временных рядов
# 180     182.0    NaN                   Безопасность компьютерных систем
# 181     183.0    NaN                  Высокопроизводительные вычисления
# 182     183.0    NaN                                           Язык SQL
# 183     182.0    NaN    Сбор и обработка данных с помощью краудсорсинга
# 184     183.0    NaN                   Безопасность компьютерных систем
# 185     183.0    NaN                                           Язык SQL
# 186     184.0    NaN                      Моделирование временных рядов
# 187     186.0    NaN    Сбор и обработка данных с помощью краудсорсинга
# 188     183.0    NaN    Сбор и обработка данных с помощью краудсорсинга
# 189     186.0    NaN                   Безопасность компьютерных систем
# 190     181.0    NaN                   Безопасность компьютерных систем
# 191     187.0    NaN                   Безопасность компьютерных систем
# 192     184.0    NaN    Сбор и обработка данных с помощью краудсорсинга
# 193     186.0    1.0                                  Теория баз данных
# 194     183.0    NaN                                           Язык SQL
# 195     185.0    NaN                      Моделирование временных рядов
# 196     188.0    NaN                                           Язык SQL
# 197     182.0    NaN                        Statistical Learning Theory
# 198     184.0    NaN                   Безопасность компьютерных систем
# 199     184.0    1.0                   Безопасность компьютерных систем
# 200     183.0    NaN                   Безопасность компьютерных систем
# 201     188.0    NaN                  Высокопроизводительные вычисления
# 202     186.0    NaN                   Безопасность компьютерных систем
# 203     188.0    NaN    Сбор и обработка данных с помощью краудсорсинга
# 204     188.0    NaN    Сбор и обработка данных с помощью краудсорсинга
# 205     184.0    1.0                      Моделирование временных рядов
# 206     185.0    NaN                                           Язык SQL
# 207     188.0    NaN                  Высокопроизводительные вычисления
# 208     187.0    NaN                   Безопасность компьютерных систем
# 209     181.0    NaN                               Матричные вычисления
# 210     182.0    NaN                   Безопасность компьютерных систем
# 211     181.0    NaN                  Высокопроизводительные вычисления
# 212     181.0    NaN                  Высокопроизводительные вычисления
# 213     188.0    NaN                   Безопасность компьютерных систем
# 214     181.0    NaN                        Statistical Learning Theory
# 215     185.0    1.0                   Безопасность компьютерных систем
# 216     181.0    NaN                                           Язык SQL
# 217     188.0    NaN  Принятие решений в условиях риска и неопределё...
# 218     185.0    NaN                   Безопасность компьютерных систем
# 219     184.0    NaN                                  Теория баз данных
# 220     188.0    NaN                                           Язык SQL
# 221     186.0    NaN                                  Теория баз данных
# 222     188.0    NaN                   Безопасность компьютерных систем
# 0         NaN    NaN                   Безопасность компьютерных систем
# 1         NaN    NaN                   Безопасность компьютерных систем
# 2         NaN    NaN                   Безопасность компьютерных систем
# 3         NaN    NaN               Глубинное обучение в обработке звука
# 4         NaN    NaN                   Безопасность компьютерных систем
# 5         NaN    NaN                   Безопасность компьютерных систем
# 6         NaN    NaN                  Высокопроизводительные вычисления
# 7         NaN    NaN                  Высокопроизводительные вычисления
# 8         NaN    NaN                        Statistical Learning Theory
# 9         NaN    NaN                  Анализ неструктурированных данных
# 10        NaN    NaN              Байесовские методы машинного обучения
# 11        NaN    NaN                  Высокопроизводительные вычисления
# 12        NaN    NaN                   Безопасность компьютерных систем
# 13        NaN    NaN                  Высокопроизводительные вычисления
# 14        NaN    NaN                   Безопасность компьютерных систем
# 15        NaN    NaN                  Высокопроизводительные вычисления
# 16        NaN    NaN                  Высокопроизводительные вычисления
# 17        NaN    NaN              Байесовские методы машинного обучения
# 18        NaN    NaN                  Анализ неструктурированных данных
# 19        NaN    NaN                  Высокопроизводительные вычисления
# 20        NaN    NaN                   Безопасность компьютерных систем
# 21        NaN    NaN                   Безопасность компьютерных систем
# 22        NaN    NaN                   Безопасность компьютерных систем
# 23        NaN    NaN                        Statistical Learning Theory
# 24        NaN    NaN                  Анализ неструктурированных данных
# 25        NaN    NaN                        Statistical Learning Theory
# 26        NaN    NaN                  Анализ неструктурированных данных
# 27        NaN    NaN              Байесовские методы машинного обучения
# 28        NaN    NaN                      Моделирование временных рядов
# 29        NaN    NaN                  Анализ неструктурированных данных
# 30        NaN    NaN                  Анализ неструктурированных данных
# 31        NaN    NaN              Байесовские методы машинного обучения
# 32        NaN    NaN              Байесовские методы машинного обучения
# 33        NaN    NaN                   Безопасность компьютерных систем
# 34        NaN    NaN              Байесовские методы машинного обучения
# 35        NaN    NaN    Сбор и обработка данных с помощью краудсорсинга
# 36        NaN    NaN                  Анализ неструктурированных данных
# 37        NaN    NaN               Глубинное обучение в обработке звука
# 38        NaN    NaN    Сбор и обработка данных с помощью краудсорсинга
# 39        NaN    NaN              Байесовские методы машинного обучения
# 40        NaN    NaN                  Анализ неструктурированных данных
# 41        NaN    NaN                  Анализ неструктурированных данных
# 42        NaN    NaN    Сбор и обработка данных с помощью краудсорсинга
# 43        NaN    NaN              Байесовские методы машинного обучения
# 44        NaN    NaN              Байесовские методы машинного обучения
# 45        NaN    NaN              Байесовские методы машинного обучения
# 46        NaN    NaN                  Анализ неструктурированных данных
# 47        NaN    NaN                  Анализ неструктурированных данных
# 48        NaN    NaN              Байесовские методы машинного обучения
# 49        NaN    NaN                        Statistical Learning Theory
# 50        NaN    NaN                  Высокопроизводительные вычисления
# 51        NaN    NaN                  Высокопроизводительные вычисления
# 52        NaN    NaN                  Высокопроизводительные вычисления
# 53        NaN    NaN    Сбор и обработка данных с помощью краудсорсинга
# 54        NaN    NaN                   Безопасность компьютерных систем
# 55        NaN    NaN              Байесовские методы машинного обучения
# 56        NaN    NaN                  Высокопроизводительные вычисления
# 57        NaN    NaN                  Анализ неструктурированных данных
# 58        NaN    NaN                  Анализ неструктурированных данных
# 59        NaN    NaN               Глубинное обучение в обработке звука
# 60        NaN    NaN                  Высокопроизводительные вычисления
# 61        NaN    NaN                        Statistical Learning Theory
# 62        NaN    NaN               Глубинное обучение в обработке звука
# ...
# 123    0.869955       NaN                                    NaN
# 124    0.950673       NaN                                    NaN
# 125    0.645740       NaN                                    NaN
# 126    0.899103       NaN                                    NaN
# 127    0.511211       NaN                                    NaN
# 128    0.991031       NaN                                    NaN
# 129    0.221973       NaN                                    NaN
# 130    0.928251       NaN                                    NaN
# 131    0.434978       NaN                                    NaN
# 132    0.778027       NaN                                    NaN
# 133    0.793722       NaN                                    NaN
# 134    0.058296       NaN                                    NaN
# 135    0.589686       NaN                                    NaN
# 136    0.434978       NaN                                    NaN
# 137    0.497758       NaN                                    NaN
# 138    0.434978       NaN                                    NaN
# 139    0.221973       NaN                                    NaN
# 140    0.376682       NaN                                    NaN
# 141    0.735426       NaN                                    NaN
# 142    0.414798       NaN                                    NaN
# 143    0.726457       NaN                                    NaN
# 144    0.401345       NaN                                    NaN
# 145    0.932735       NaN                                    NaN
# 146    0.793722       NaN                                    NaN
# 147    0.910314       NaN                                    NaN
# 148    0.204036       NaN                                    NaN
# 149    0.778027       NaN                                    NaN
# 150    0.735426       NaN                                    NaN
# 151    0.071749       NaN                                    NaN
# 152    0.401345       NaN                                    NaN
# 153    0.284753       NaN                                    NaN
# 154    0.221973       NaN                                    NaN
# 155    0.614350       NaN                                    NaN
# 156    0.964126       NaN                                    NaN
# 157    0.448430       NaN                                    NaN
# 158    0.022422       NaN                                    NaN
# 159    0.065022       NaN                                    NaN
# 160    0.883408       NaN                                    NaN
# 161    0.562780       NaN                                    NaN
# 162    0.946188       NaN                                    NaN
# 163    0.544843       NaN                                    NaN
# 164    0.757848       NaN                                    NaN
# 165    0.556054       NaN                                    NaN
# 166    0.968610       NaN                                    NaN
# 167    0.340807       NaN                                    NaN
# 168    0.856502       NaN                                    NaN
# 169    0.892377       NaN                                    NaN
# 170    0.748879       NaN                                    NaN
# 171    0.470852       NaN                                    NaN
# 172    0.757848       NaN                                    NaN
# 173    0.598655       NaN                                    NaN
# 174    0.910314       NaN                                    NaN
# 175    0.309417       NaN                                    NaN
# 176    0.910314       NaN                                    NaN
# 177    0.266816       NaN                                    NaN
# 178    0.327354       NaN                                    NaN
# 179    0.414798       NaN                                    NaN
# 180    0.266816       NaN                                    NaN
# 181    0.309417       NaN                                    NaN
# 182    0.701794       NaN                                    NaN
# 183    0.141256       NaN                                    NaN
# 184    0.170404       NaN                                    NaN
# 185    0.863229       NaN                                    NaN
# 186    0.423767       NaN                                    NaN
# 187    0.132287       NaN                                    NaN
# 188    0.614350       NaN                                    NaN
# 189    0.275785       NaN                                    NaN
# 190    0.354260       NaN                                    NaN
# 191    0.116592       NaN                                    NaN
# 192    0.423767       NaN                                    NaN
# 193    0.744395       NaN                                    NaN
# 194    0.941704       NaN                                    NaN
# 195    0.275785       NaN                                    NaN
# 196    0.614350       NaN                                    NaN
# 197    0.295964       NaN                                    NaN
# 198    0.204036       NaN                                    NaN
# 199    0.836323       NaN                                    NaN
# 200    0.132287       NaN                                    NaN
# 201    0.690583       NaN                                    NaN
# 202    0.123318       NaN                                    NaN
# 203    0.852018       NaN                                    NaN
# 204    0.614350       NaN                                    NaN
# 205    0.488789       NaN                                    NaN
# 206    0.820628       NaN                                    NaN
# 207    0.327354       NaN                                    NaN
# 208    0.719731       NaN                                    NaN
# 209    0.049327       NaN                                    NaN
# 210    0.026906       NaN                                    NaN
# 211    0.829596       NaN                                    NaN
# 212    0.719731       NaN                                    NaN
# 213    0.544843       NaN                                    NaN
# 214    0.670404       NaN                                    NaN
# 215    0.578475       NaN                                    NaN
# 216    0.569507       NaN                                    NaN
# 217    0.995516       NaN                                    NaN
# 218    0.986547       NaN                                    NaN
# 219    0.589686       NaN                                    NaN
# 220    0.863229       NaN                                    NaN
# 221    0.504484       NaN                                    NaN
# 222    0.221973       NaN                                    NaN
# 0      0.963768     172.0                                 DevOps
# 1      0.666667     176.0                                 DevOps
# 2      0.782609     172.0                                 DevOps
# 3      0.427536     171.0                                 DevOps
# 4      0.789855     176.0                                 DevOps
# 5      0.688406     176.0                                 DevOps
# 6      0.594203     175.0                                 DevOps
# 7      0.268116     175.0                                 DevOps
# 8      0.000000     173.0  Введение в дифференциальную геометрию
# 9      0.818841     172.0                                 DevOps
# 10     0.637681     172.0                                 DevOps
# 11     0.181159     175.0                                 DevOps
# 12     0.253623     175.0                                 DevOps
# 13     0.826087     173.0                                 DevOps
# 14     0.115942     176.0                                 DevOps
# 15     0.144928     175.0  Введение в дифференциальную геометрию
# 16     0.307971     173.0                                 DevOps
# 17     0.619565     173.0  Введение в дифференциальную геометрию
# 18     0.420290     175.0         Соревновательный анализ данных
# 19     0.884058     176.0         Соревновательный анализ данных
# 20     0.072464     174.0                                 DevOps
# 21     0.260870     173.0                                 DevOps
# 22     0.869565     177.0                                 DevOps
# 23     0.192029     173.0  Введение в дифференциальную геометрию
# 24     0.130435     171.0         Соревновательный анализ данных
# 25     0.155797     173.0  Введение в дифференциальную геометрию
# 26     0.275362     171.0         Соревновательный анализ данных
# 27     0.021739     173.0         Соревновательный анализ данных
# 28     0.307971     175.0  Введение в дифференциальную геометрию
# 29     0.855072     172.0                                 DevOps
# 30     0.913043     172.0                                 DevOps
# 31     0.351449     171.0                                 DevOps
# 32     0.710145     172.0                                 DevOps
# 33     0.601449     172.0                                 DevOps
# 34     0.547101     172.0                                 DevOps
# 35     0.739130     172.0                                 DevOps
# 36     0.547101     172.0                                 DevOps
# 37     0.405797     171.0         Соревновательный анализ данных
# 38     0.797101     172.0         Соревновательный анализ данных
# 39     0.434783     171.0         Соревновательный анализ данных
# 40     0.467391     171.0                                 DevOps
# 41     0.971014     172.0         Соревновательный анализ данных
# 42     0.862319     172.0         Соревновательный анализ данных
# 43     0.166667     171.0                                 DevOps
# 44     0.028986     171.0                                 DevOps
# 45     0.485507     171.0         Соревновательный анализ данных
# 46     0.557971     171.0                                 DevOps
# 47     0.398551     172.0                                 DevOps
# 48     0.221014     171.0                                 DevOps
# 49     0.699275     173.0         Соревновательный анализ данных
# 50     0.007246     175.0                                 DevOps
# 51     0.137681     175.0                                 DevOps
# 52     0.155797     175.0                                 DevOps
# 53     0.442029     172.0         Соревновательный анализ данных
# 54     0.108696     173.0  Введение в дифференциальную геометрию
# 55     0.210145     171.0                                 DevOps
# 56     0.583333     176.0                                 DevOps
# 57     0.934783     172.0                                 DevOps
# 58     0.094203     171.0                                 DevOps
# 59     0.202899     177.0  Введение в дифференциальную геометрию
# 60     0.322464     175.0                                 DevOps
# 61     0.391304     171.0         Соревновательный анализ данных
# 62     0.173913     175.0                                 DevOps
# 63     0.413043     176.0                                 DevOps
# 64     0.336957     173.0  Введение в дифференциальную геометрию
# 65     0.521739     173.0  Введение в дифференциальную геометрию
# 66     0.101449     175.0                                 DevOps
# 67     0.760870     177.0  Введение в дифференциальную геометрию
# 68     0.746377     176.0                                 DevOps
# 69     0.775362     173.0  Введение в дифференциальную геометрию
# 70     0.978261     173.0                                 DevOps
# 71     0.572464     172.0         Соревновательный анализ данных
# 72     0.536232     173.0  Введение в дифференциальную геометрию
# 73     0.608696     174.0         Соревновательный анализ данных
# 74     0.510870     176.0                                 DevOps
# 75     0.510870     171.0                                 DevOps
# 76     0.833333     172.0         Соревновательный анализ данных
# 77     0.286232     171.0                                 DevOps
# 78     0.583333     172.0                                 DevOps
# 79     0.286232     171.0                                 DevOps
# 80     0.297101     172.0         Соревновательный анализ данных
# 81     0.221014     171.0         Соревновательный анализ данных
# 82     0.050725     174.0  Введение в дифференциальную геометрию
# 83     0.373188     175.0         Соревновательный анализ данных
# 84     0.456522     171.0         Соревновательный анализ данных
# 85     0.192029     175.0                                 DevOps
# 86     0.630435     172.0                                 DevOps
# 87     0.731884     172.0                                 DevOps
# 88     0.927536     176.0                                 DevOps
# 89     0.891304     176.0                                 DevOps
# 90     0.644928     172.0         Соревновательный анализ данных
# 91     0.362319     175.0                                 DevOps
# 92     0.652174     174.0                                 DevOps
# 93     0.724638     172.0                                 DevOps
# 94     0.677536     175.0         Соревновательный анализ данных
# 95     0.322464     174.0                                 DevOps
# 96     0.351449     176.0                                 DevOps
# 97     0.528986     171.0                                 DevOps
# 98     0.807971     174.0                                 DevOps
# 99     0.619565     172.0                                 DevOps
# 100    0.014493     171.0                                 DevOps
# 101    0.492754     176.0                                 DevOps
# 102    0.807971     174.0                                 DevOps
# 103    0.699275     174.0                                 DevOps
# 104    0.043478     173.0                                 DevOps
# 105    0.949275     173.0                                 DevOps
# 106    0.336957     171.0         Соревновательный анализ данных
# 107    0.231884     171.0                                 DevOps
# 108    0.061594     175.0                                 DevOps
# 109    0.079710     171.0         Соревновательный анализ данных
# 110    0.760870     174.0                                 DevOps
# 111    0.467391     175.0                                 DevOps
# 112    0.847826     173.0         Соревновательный анализ данных
# 113    0.384058     175.0                                 DevOps
# 114    0.449275     174.0  Введение в дифференциальную геометрию
# 115    0.902174     174.0                                 DevOps
# 116    0.478261     176.0                                 DevOps
# 117    0.992754     174.0                                 DevOps
# 118    0.876812     176.0                                 DevOps
# 119    0.760870     174.0                                 DevOps
# 120    0.239130     176.0                                 DevOps
# 121    0.246377     175.0                                 DevOps
# 122    0.123188     175.0                                 DevOps
# 123    0.956522     174.0         Соревновательный анализ данных
# 124    0.036232     175.0                                 DevOps
# 125    0.717391     172.0         Соревновательный анализ данных
# 126    0.086957     175.0                                 DevOps
# 127    0.659420     172.0         Соревновательный анализ данных
# 128    0.942029     174.0                                 DevOps
# 129    0.061594     175.0                                 DevOps
# 130    0.565217     175.0                                 DevOps
# 131    0.902174     171.0                                 DevOps
# 132    0.500000     171.0         Соревновательный анализ данных
# 133    0.920290     174.0                                 DevOps
# 134    0.840580     174.0                                 DevOps
# 135    0.677536     173.0         Соревновательный анализ данных
# 136    0.985507     172.0                                 DevOps
# 137    0.373188     176.0         Соревновательный анализ данных

# %% [markdown]
# Нередко работы с данными начинают с поиска пропущенных значений (NaN и др.) и их заполнения. Для начала посмотрим на их наличие:

# %%
data.isna().sum()
# Out:
# timestamp          0
# id                 0
# rating             0
# 18_group         138
# is_mi            343
# fall_1             0
# fall_2             0
# fall_3             0
# spring_1           0
# spring_2           0
# spring_3           0
# is_first_time      2
# percentile         0
# 17_group         223
# blended          223
# dtype: int64

# %% [markdown]
# Видно, что тут содержательных пропусков нет — есть только проблемы с колонками, специфичными для одного из курсов.
#
# Заполнять пропуски необходимо в соответствии со смыслом колонки. Можно заполнять с помощью среднего, медианного, константного или других значений. Для этого обычно используется метод ```fillna()``` с которым вы познакомитесь в домашнем задании.

# %% [markdown]
# Также для разведочного анализа может помочь метод ```groupby(column)```.
#
# Он группирует объекты по указанной(-ым) колонке(-ам). Необходимо также указать какую статистику для группировки выводить. Это может быть количество (count), среднее (mean) или другие. Из огромной функциональности этого метода разберем только несколько базовых приемов:

# %%
data.groupby('fall_1').count()[['id', 'is_mi']]
# Out:
#                                                      id  is_mi
# fall_1
# Statistical Learning Theory                          26      1
# Анализ неструктурированных данных                    32      0
# Байесовские методы машинного обучения                17      0
# Безопасность компьютерных систем                    110      4
# Высокопроизводительные вычисления                    42      0
# Глубинное обучение в обработке звука                 12      0
# Матричные вычисления                                 14      1
# Моделирование временных рядов                        24      7
# Принятие решений в условиях риска и неопределён...    5      0
# Сбор и обработка данных с помощью краудсорсинга      35      1
# Теория баз данных                                    13      2
# Язык SQL                                             31      2

# %% [markdown]
# *Какие выводы вы можете сделать отсюда?*

# %% [markdown]
# Сделаем ```groupby``` с усреднением:

# %%
data.groupby(by='fall_1').mean()
# Out:
# <ipython-input-98-8c91308e0230>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(by='fall_1').mean()
#                                                          rating    18_group  \
# fall_1
# Statistical Learning Theory                          886.769231  183.428571
# Анализ неструктурированных данных                   1124.000000         NaN
# Байесовские методы машинного обучения               1190.647059         NaN
# Безопасность компьютерных систем                     785.872727  184.481481
# Высокопроизводительные вычисления                    968.309524  184.055556
# Глубинное обучение в обработке звука                1163.250000         NaN
# Матричные вычисления                                 671.857143  183.357143
# Моделирование временных рядов                        671.125000  184.869565
# Принятие решений в условиях риска и неопределён...   762.600000  186.333333
# Сбор и обработка данных с помощью краудсорсинга      781.628571  185.038462
# Теория баз данных                                    629.384615  184.000000
# Язык SQL                                             609.612903  185.258065
#
#                                                     is_mi  percentile  \
# fall_1
# Statistical Learning Theory                           1.0    0.509294
# Анализ неструктурированных данных                     NaN    0.587523
# Байесовские методы машинного обучения                 NaN    0.386402
# Безопасность компьютерных систем                      1.0    0.464152
# Высокопроизводительные вычисления                     NaN    0.399445
# Глубинное обучение в обработке звука                  NaN    0.460447
# Матричные вычисления                                  1.0    0.386931
# Моделирование временных рядов                         1.0    0.492092
# Принятие решений в условиях риска и неопределён...    NaN    0.811055
# Сбор и обработка данных с помощью краудсорсинга       1.0    0.473438
# Теория баз данных                                     1.0    0.602277
# Язык SQL                                              1.0    0.704759
#
#                                                       17_group
# fall_1
# Statistical Learning Theory                         173.000000
# Анализ неструктурированных данных                   172.593750
# Байесовские методы машинного обучения               171.411765
# Безопасность компьютерных систем                    174.413793
# Высокопроизводительные вычисления                   174.958333
# Глубинное обучение в обработке звука                172.916667
# Матричные вычисления                                       NaN
# Моделирование временных рядов                       175.000000
# Принятие решений в условиях риска и неопределён...  175.000000
# Сбор и обработка данных с помощью краудсорсинга     172.555556
# Теория баз данных                                          NaN
# Язык SQL                                                   NaN

# %% [markdown]
# Отсюда мы узнаём среднюю перцентиль для того или иного курса по выбору.
# Обратите внимание, что средний рейтинг тут не очень показателен из-за разных его распределений у разных годов обучения.
#
# Что выводится в следующей строке?

# %%
data.groupby(by='fall_1').count()[['17_group', '18_group']].sum(axis=1)
# Out:
# fall_1
# Statistical Learning Theory                              26
# Анализ неструктурированных данных                        32
# Байесовские методы машинного обучения                    17
# Безопасность компьютерных систем                        110
# Высокопроизводительные вычисления                        42
# Глубинное обучение в обработке звука                     12
# Матричные вычисления                                     14
# Моделирование временных рядов                            24
# Принятие решений в условиях риска и неопределённости      5
# Сбор и обработка данных с помощью краудсорсинга          35
# Теория баз данных                                        13
# Язык SQL                                                 31
# dtype: int64

# %% [markdown]
# Полезным бывает посмотреть на основные статистики по каждому *числовому*  признаку (столбцу). Метод ```describe``` позволяет быстро сделать это:

# %%
data.describe()
# Out:
#                            timestamp       rating    18_group  is_mi  \
# count                            361   361.000000  223.000000   18.0
# mean   2020-05-18 05:08:48.082047232   842.387812  184.520179    1.0
# min       2020-05-14 20:23:21.662000   495.000000  181.000000    1.0
# 25%    2020-05-17 17:40:31.867000064   634.000000  183.000000    1.0
# 50%    2020-05-18 19:23:38.273999872   702.000000  185.000000    1.0
# 75%       2020-05-18 22:24:55.160000  1107.000000  187.000000    1.0
# max       2020-05-24 01:21:31.946000  1456.000000  188.000000    1.0
# std                              NaN   256.919279    2.271701    0.0
#
#        percentile    17_group
# count  361.000000  138.000000
# mean     0.497230  173.355072
# min      0.000000  171.000000
# 25%      0.246637  172.000000
# 50%      0.497758  173.000000
# 75%      0.746377  175.000000
# max      0.995516  177.000000
# std      0.289060    1.795374

# %% [markdown]
# *Какие элементы таблицы выше могут быть полезны? Для чего?*

# %% [markdown]
# Студентам специализации МОП (машинное обучение и приложения) нельзя выбирать курс "Машинное обучение 2" в качестве весеннего курса по выбору. Давайте проверим, есть ли те, кто попытался:

# %%
# !wget  -O 'ml_students_anon.xlsx' -q 'https://www.dropbox.com/s/izc21kik0b8iw10/_ml_students_anon.xlsx?dl=0'

ml_students = pd.read_excel('ml_students_anon.xlsx')
ml_students.head()
# Out:
#                                  id  is_ml_student
# 0  2ba0a356c95af4fe74272e708082086f           True
# 1  a0c56e8aa03ea6c1f5e8462914472075           True
# 2  cabc5ea85cac3029dc2aecc4955f9cf3           True
# 3  4ab8340cfb08da86c14a2cc3c3fad908           True
# 4  b6fcd3cdcbbd950b4207acb65ee12d03           True

# %% [markdown]
# Если вы знакомы с SQL, то знаете, что там крайне часто используется операция JOIN для соединения нескольких таблиц по тому или иному значению. В pandas такое тоже есть, функция называется ```merge```.
#
# У нас есть две таблицы: (1) приоритеты студентов по элективам и (2) специализации, на которые распределены студенты. Эти таблицы содержат разную информацию про студентов, но в обеих конкретный студент имеет один и тот же ID. Допустим, мы теперь хотим соединить эти таблицы — то есть получить новую таблицу, в которой для каждого студента есть информация и о приоритетах по элективам, и о его специализации. Как раз для этого и понадобится операция ```merge```.
#
# Идея соединения таблиц также отражена на картинке ниже.

# %% [markdown]
# <img src="https://i.imgur.com/WYyBFTE.png" style="width: 400px">

# %%
data = data.merge(ml_students, on='id', how='left')
data.head()
# Out:
#                 timestamp                                id  rating  18_group  \
# 0 2020-05-15 01:12:50.543  93ff79a51cd602f1dd3028ba2c129503   704.0     181.0
# 1 2020-05-15 02:46:48.066  26b01b1c4cd5656bab18d24c548834fb   646.0     181.0
# 2 2020-05-15 03:12:41.480  30f3653fc176d54e89ac3179c455c6dd   624.0     185.0
# 3 2020-05-15 04:43:08.994  1528f0eaa027580820ccf0d92a53ad68   579.0     182.0
# 4 2020-05-15 07:47:17.197  496ea4f0d4abe264b1bb1b80eb3830c5   632.0     183.0
#
#    is_mi                             fall_1  \
# 0    NaN                           Язык SQL
# 1    NaN  Высокопроизводительные вычисления
# 2    NaN   Безопасность компьютерных систем
# 3    NaN        Statistical Learning Theory
# 4    NaN  Высокопроизводительные вычисления
#
#                               fall_2                         fall_3  \
# 0  Высокопроизводительные вычисления           Матричные вычисления
# 1   Безопасность компьютерных систем                       Язык SQL
# 2               Матричные вычисления  Моделирование временных рядов
# 3  Высокопроизводительные вычисления           Матричные вычисления
# 4   Безопасность компьютерных систем              Теория баз данных
#
#                  spring_1                spring_2             spring_3  \
# 0  Дискретная оптимизация        Численные методы  Машинное обучение 2
# 1  Дискретная оптимизация        Численные методы  Машинное обучение 2
# 2  Дискретная оптимизация     Машинное обучение 2     Численные методы
# 3  Дискретная оптимизация        Численные методы  Машинное обучение 2
# 4       Компьютерные сети  Дискретная оптимизация     Численные методы
#
#   is_first_time  percentile  17_group blended is_ml_student
# 0            Да    0.179372       NaN     NaN           NaN
# 1           Нет    0.504484       NaN     NaN           NaN
# 2            Да    0.679372       NaN     NaN           NaN
# 3            Да    0.876682       NaN     NaN           NaN
# 4            Да    0.598655       NaN     NaN           NaN

# %%
data[(data['is_ml_student'] == True) &
     (
         (data['spring_1'] == 'Машинное обучение 2') | \
         (data['spring_2'] == 'Машинное обучение 2') | \
         (data['spring_3'] == 'Машинное обучение 2')
     )
]
# Out:
#                   timestamp                                id  rating  \
# 20  2020-05-15 21:55:16.699  f0f6f3881894172a0f04e79b554b49e6   676.0
# 27  2020-05-16 13:02:24.706  5daee1bd98559bb2c52373e416942225   659.0
# 119 2020-05-18 20:34:07.220  fc2c60b8004aa91bc272df84628621ff   642.0
# 137 2020-05-18 21:24:23.667  6ed89e424179b0510e3f7c0cb7369ad6   647.0
# 179 2020-05-18 23:01:03.214  abceddfa2fc4eae8cff4a4e712abb3fb   663.0
#
#      18_group  is_mi                                           fall_1  \
# 20      181.0    NaN                 Безопасность компьютерных систем
# 27      182.0    NaN  Сбор и обработка данных с помощью краудсорсинга
# 119     183.0    NaN                                         Язык SQL
# 137     187.0    NaN                    Моделирование временных рядов
# 179     183.0    NaN                    Моделирование временных рядов
#
#                                                 fall_2  \
# 20     Сбор и обработка данных с помощью краудсорсинга
# 27                         Statistical Learning Theory
# 119    Сбор и обработка данных с помощью краудсорсинга
# 137                               Матричные вычисления
# 179  Принятие решений в условиях риска и неопределё...
#
#                                                 fall_3  \
# 20   Принятие решений в условиях риска и неопределё...
# 27                       Моделирование временных рядов
# 119                        Statistical Learning Theory
# 137                                           Язык SQL
# 179                        Statistical Learning Theory
#
#                     spring_1                                     spring_2  \
# 20       Машинное обучение 2                             Численные методы
# 27       Машинное обучение 2  Промышленное программирование на языке Java
# 119       Системы баз данных                          Машинное обучение 2
# 137  Анализ данных в бизнесе  Промышленное программирование на языке Java
# 179      Машинное обучение 2  Промышленное программирование на языке Java
#
#                                        spring_3 is_first_time  percentile  \
# 20   Дополнительные главы прикладной статистики            Да    0.336323
# 27                      Анализ данных в бизнесе           Нет    0.443946
# 119                     Анализ данных в бизнесе           Нет    0.522422
# 137                         Машинное обучение 2            Да    0.497758
# 179  Дополнительные главы прикладной статистики            Да    0.414798
#
#      17_group blended is_ml_student
# 20        NaN     NaN          True
# 27        NaN     NaN          True
# 119       NaN     NaN          True
# 137       NaN     NaN          True
# 179       NaN     NaN          True

# %% [markdown]
# Сохраним полученную таблицу, чтобы вы могли продолжить с ней работу дома:

# %%
data.to_excel('end_seminar.xlsx', index=False)
